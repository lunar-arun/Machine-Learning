# %% [markdown]
# # Clustering

# %% [markdown]
#     Clustering : Technique that groups similar things(data points).
#         These are of two types :
#             Hard Cluster   Soft Cluster
#
#     Hard Clustering : one data point can belong to one cluster only.
#
#     Soft Clustering : each data point has probability or likelihood value that decided which cluster it belongs.

# %% [markdown]
# ![image.png](attachment:image.png)
