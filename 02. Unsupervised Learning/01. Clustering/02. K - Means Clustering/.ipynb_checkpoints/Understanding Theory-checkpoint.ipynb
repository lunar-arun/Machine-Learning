# %% [markdown]
# # K-Means Clustering

# %% [markdown]
#     Used to solve clustering problem where it follows a simple procedure of classifying a given data points into number of cluster as "k" is defined beforehand.
#
#     It's an unsupervised learning algorithm
#
#     K-means identifies k number of centroids
#
#     The ‘means’ in the K-means refers to averaging of the data that is finding the centroid

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     The main objective of the K-Means algorithm is to minimize the sum of distances between the points and their respective cluster centroid.

# %% [markdown]
#     Step-1 : Choose the number of clusters (k) you want to identify in your dataset
#     Step-2 : Randomly initialize k centroids (points) in your feature space. These represent the initial cluster centers.
#     Step-3 : Calculate the minimum distance between each data point and each centroid and assign each of them to closest cluster.
#     Step-4 : Recalculate the centroids of the clusters by taking the mean of all data points assigned to each cluster.
#     Step-5 : New centroids will become the new cluster centers and repeat step 3 and 4 until convergence is achieved.
#
#     Convergence occurs when the centroids no longer change significantly or when a specified number of iterations is reached.

# %% [markdown]
#     METHODS TO FIND VALUES OF K
#
#         ELBOW METHOD :
#             used to determine this optimal value of k.
#             involves running the algorithm multiple times over a loop, with an increasing number of cluster.
#             plotting a clustering score as a function of the number of clusters.
#             we encounter ambiguous situation while using Elbow method
