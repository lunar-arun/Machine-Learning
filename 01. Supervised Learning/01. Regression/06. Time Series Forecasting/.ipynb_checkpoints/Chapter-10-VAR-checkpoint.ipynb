# %% [markdown]
#     In two time series have a bidirectional relationship,meaning that time series t1 is a predictor of time series t2, and time series t2 is also a predictor for time series t1.
#
#     Then we need to take output of time series simltaneously.
#
#     This brings to...
#     The vector autoregression model VAR(p) models : it's the relationship of two or more time series.
#     Each time series has an impact on the others, meaning the past values of one affect the other and vice versa.
#
#     On general we can take VAR(p) as AR(p) model, with order p.
#
#     AR(p) => yt = C + φ1yt –1 + φ2yt –2 +⋅⋅⋅+ φpyt–p + ϵt
#
#     VAR(p) => using matrix notation to represent two or more series.

# %% [markdown]
# ![image.png](attachment:image.png)
